# %% [markdown]
# # 데이터 불러오기 및 전처리

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import torch
from tqdm.auto import tqdm
import random
import os

def reset_seeds(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

DATA_PATH = "/content/drive/MyDrive/멀티캠퍼스 자료/Machine Learning/data/"
SEED = 42

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
text_ft = pd.read_csv(f"{DATA_PATH}keyword_list.txt")
text_ft
# Out:
#     ['꾸밈없 즐기 뽐내 소개 가사 돋보이 그러 제공 대신 채우 신시사이저 등장 내비치 이하 키우 장난 일으키 부연 비유 노래 신드롬 탈피 진정 패션 현지 잡지 매거진 가깝 이중 뉴진스는 강조 걸그룹 서로 매개체 코러스 미학 언어 음악 향상 매력 표현 홈페이지 게재 선사 단체 하나 공개 표지 공감 만큼 기여 기자 적합 이재훈 의미 장식 데뷔 금지'  \
# 0     '진단 의사 증상 대응 것이다피프티피프티가 상태 찍히 보내 싸늘하 밟히 워너 하다...
# 1     '출시 하니 소개 앞서 비치 샤이 엽서 꾸미 선보이 사지 뉴진스를 뉴진스서울뉴스 ...
# 2     '참가 참석 세계 만들 화제 글로벌 현장 스튜디오잼머쉬룸컴퍼니의 자리매김 소개 참...
# 3     '르세라핌과 관리 케어 요즘 글로벌 세계 관련 최근 진행 표했다에스엠터테인먼트에서...
# 4     '김재환 서울 솔직하 김선형 아이 뿌듯하 김지혜 전하 살아나 그러 말씀 이예지 지...
# ..                                                 ...
# 250   '페스티벌 투데이 뮤직비디오 보여주 카밀로 그래미 전하 싱어송라이터 서머 작곡가 ...
# 251   '사진 기자 홈페이지 영상 로고 유튜브 브랜드 소개 입고 코리아 예나 앰배서더 스...
# 252   '배우 이끌 코치 영화 시청자 당부 코치진 스타 등장 꾸밈없 주목 즐기 아이키 앞...
# 253   '연합뉴스 현지 뉴스 기자 영화 공개 발표 최신 엔터테인먼트 여자 노래 뮤직 밝히...
# 254   '방시혁 지현이 서연이 좋아하 그리 반가워하 엊그제 컬래버를 코치진 보내 아이 도...
#
#      Unnamed: 1
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 250         NaN
# 251         NaN
# ...

# %%
train = pd.read_csv(f"{DATA_PATH}뉴진스_202306_200p.csv")

# %%
train = pd.DataFrame(train)

# %%
train['title']
# Out:
# 0      \n\t\t\t'새로운 유전자' 뉴진스 "K팝, 언어장벽 넘어 소통하는 매개체"\n...
# 1      \n\t\t\t“뉴진스도 아니고…” 피프티피프티 정산주장, 사실상 ‘배은망덕’ 낙인...
# 2           \n\t\t\t뉴진스, 비치 백에 CD 담은 파격…"소장 욕구 자극"\n\t\t
# 3      \n\t\t\t[Y현장] 'R U Next?', 르세라핌·뉴진스 만든 하이브 걸그룹...
# 4      \n\t\t\t뉴진스 후배 뽑는 과정 대공개…하이브 오디션 '알유넥스트'[종합]\n...
#                              ...
# 251    \n\t\t\t그래미 5관왕 주인공 존 바티스트, 뉴진스와 함께한 코카콜라 싱글 발...
# 252    \n\t\t\t뉴진스 민지, 937만 원 점프수트 입고 명품 자랑…20살의 플렉스\...
# 253    \n\t\t\t‘알유넥스트’, 하이브 넥스트 걸그룹 향한 도전...관전 포인트3\n...
# 254    \n\t\t\t세븐틴 'FML', 빌보드 앨범 차트 8주 연속 진입…자체 최장 기록...
# 255    \n\t\t\t'알유넥스트' 데뷔할 6명은 과연 누구...22명 연습생 공개 (종합...
# Name: title, Length: 256, dtype: object

# %%
train['title']
# Out:
# 0      \n\t\t\t'새로운 유전자' 뉴진스 "K팝, 언어장벽 넘어 소통하는 매개체"\n...
# 1      \n\t\t\t“뉴진스도 아니고…” 피프티피프티 정산주장, 사실상 ‘배은망덕’ 낙인...
# 2           \n\t\t\t뉴진스, 비치 백에 CD 담은 파격…"소장 욕구 자극"\n\t\t
# 3      \n\t\t\t[Y현장] 'R U Next?', 르세라핌·뉴진스 만든 하이브 걸그룹...
# 4      \n\t\t\t뉴진스 후배 뽑는 과정 대공개…하이브 오디션 '알유넥스트'[종합]\n...
#                              ...
# 251    \n\t\t\t그래미 5관왕 주인공 존 바티스트, 뉴진스와 함께한 코카콜라 싱글 발...
# 252    \n\t\t\t뉴진스 민지, 937만 원 점프수트 입고 명품 자랑…20살의 플렉스\...
# 253    \n\t\t\t‘알유넥스트’, 하이브 넥스트 걸그룹 향한 도전...관전 포인트3\n...
# 254    \n\t\t\t세븐틴 'FML', 빌보드 앨범 차트 8주 연속 진입…자체 최장 기록...
# 255    \n\t\t\t'알유넥스트' 데뷔할 6명은 과연 누구...22명 연습생 공개 (종합...
# Name: title, Length: 256, dtype: object

# %%
train['content']
# Out:
# 0      [\n美 패션잡지 'V 매거진' 7/8월호 표지 장식·인터뷰 \n[서울=뉴시스] 뉴...
# 1      [\n \n그룹 피프티피프티. 소속사 제공빌보드를 수놓은 ‘괴물 신인’ 피프티피프티...
# 2      [\n \n뉴진스(서울=뉴스1) 황미현 기자 = 뉴진스(NewJeans)가 소장욕구...
# 3      [\n \n르세라핌, 뉴진스 이을 하이브의 넥스트 걸그룹은? JTBC 서바이벌 프로...
# 4      [\n빌리프랩 연습생 22명 출연글로벌 시청자 투표도 반영총 10회 분량·30일 첫...
#                              ...
# 251    [\n \n유니버설제64회 그래미 최다 수상자 재즈 뮤지션 존 바티스트( Jon B...
# 252    [\n \n[앳스타일 김예나 기자] 올해 스무 살의 그룹 뉴진스 멤버 민지가 자신의...
# 253    [\n \n ‘알유넥스트’. 사진l빌리프랩‘알유넥스트(R U Next?)’ 첫 방송...
# 254    [\n피프티 피프티 '큐피드', '핫100' 24위 \n그룹 세븐틴[플레디스엔터테인...
# 255    [\n \nJTBC '알유넥스트' 캡처 [헤럴드POP=임채령 기자]22명의 연습생들...
# Name: content, Length: 256, dtype: object

# %%
train['title'] = train['title'].str.replace("[^a-zA-Z가-힣0-9 .,!?\'\"]" , "",regex=True)

# %%
train["content"] = train["content"].str.replace("[^a-zA-Z가-힣0-9 .,!?\'\"]" , "",regex=True)

# %%
# !pip install kiwipiepy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 39.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for kiwipiepy-model: filename=kiwipiepy_model-0
 '방시혁 지현이 서연이 좋아하 그리 반가워하 엊그제 컬래버를 코치진 보내 아이 도도하 이루 김재현 그러 알유넥스트 잇지 이날 김재환 정은 소개 이로하 미팅 지우 지금 원희 만두 헤럴드 넥스트 임하 이현 노윤아 혜원 저기 필요 선곡 등장 코치 샤넬 앰버 저희 호응 아이키 모아 어리 생기 아이돌 조이 평소 데뷔 규리 레드벨벳 보컬 노래 팬클럽 선보이 본격 걸그룹']

# %%
train['title']

total_text = []
for sentence in train['title']:
    total_text.append(sentence)

# %% [markdown]
# # 비지도 추출 방식

# %% [markdown]
# ##  A. LDA 예시작업
#
# - LDA : 확률적 그래픽 모델로, 문서 집합을 주제와 단어의 분포로 설명하는 모델
# - LSA : 행렬 분해 기반의 차원 축소 기법을 사용하여 문서들의 의미적 관계를 파악 -> 문서를 단어-문서 행렬로 표현하고, 이 행렬을 저차원으로 압축 -> 문서들의 의미적 유사성을 반영

# %%
# !pip install kiwipiepy

# %%
from kiwipiepy import Kiwi
kiwi = Kiwi()

# %%
#텍스트 분석 결과를 담고 있음
text = train["content"][0]
result = kiwi.tokenize(text)

# %%
from kiwipiepy.utils import Stopwords
stopwords =  Stopwords()
# stopwords.stopwords # 불용어 리스트

# %% [markdown]
# ### VV, VA, MAG

# %%
total_keyword = []

for idx, text in enumerate(total_text) :   #256 개의 기사 (각 기사:text)
    result = kiwi.tokenize(text,stopwords=stopwords) #한 기사에 대한 분석 결과
    # print(idx,'번째 기사 형태소 개수 :',len(result))
    tmp = [token.form for token in result if token.tag in ['VV','VA','MAG']] #한 기사 형태소 리스트
    for idx, word in enumerate(tmp) :
        total_keyword.append(word) #모든 기사 형태소를 total_keyword에 담음

# %%
# total_keyword

# %%
news_title = []

for sentence in train['title']:
    news_title.append(sentence)

# %%
total_title = []

for idx, text in enumerate(news_title) :   #256 개의 기사 (각 기사:text)
    result = kiwi.tokenize(text,stopwords=stopwords) #한 기사에 대한 분석 결과
    # print(idx,'번째 기사 형태소 개수 :',len(result))
    tmp = [token.form for token in result if token.tag in ['VV','VA','MAG']] #한 기사 형태소 리스트
    for idx, word in enumerate(tmp) :
        total_title.append(word) #모든 기사 형태소를 total_keyword에 담음

# %%
total_title
# Out:
# ['넘',
#  '만드',
#  '다르',
#  '찾',
#  '어떻',
#  '알',
#  '빠지',
#  '보이',
#  '있',
#  '잘',
#  '오늘',
#  '말',
#  '모르',
#  '찾',
#  '찾',
#  '깜짝',
#  '또',
#  '찾',
#  '예쁘',
#  '좋',
#  '해맑',
#  '왜',
#  '하필',
#  '몰리',
#  '남다르',
#  '향하',
#  '쓸',
#  '넘기',
#  '빚',
#  '이러',
#  '안',
#  '반하',
#  '설레',
#  '너무',
#  '감추',
#  '예쁘',
#  '빠져들',
#  '만드',
#  '열리',
#  '들어오',
#  '쓸',
#  '넘기',
#  '예쁘',
#  '있',
#  '안',
#  '느끼',
#  '주',
#  '넘치',
#  '쎄',
#  '함께',
#  '직접',
#  '먼저',
#  '보이',
#  '달구',
#  '나',
#  '드높이',
#  '매일',
#  '담아내',
#  '빛나',
#  '놀',
#  '들썩',
#  '희',
#  '많',
#  '픽',
#  '이끌',
#  '떼',
#  '크',
#  '잘',
#  '나가',
#  '비',
#  '없이',
#  '꽉',
#  '차',
#  '달구',
#  '다시',
#  '일으키',
#  '오르',
#  '나오',
#  '달구',
#  '있',
#  '만드',
#  '아직',
#  '모르',
#  '밝히',
#  '못지않',
#  '타',
#  '타',
#  '가',
#  '머지않',
#  '함께',
#  '즐기',
#  '마치',
#  '쓰',
#  '또',
#  '반하',
#  '나',
#  '잘못',
#  '톡',
#  '타',
#  '타',
#  '가',
#  '빠지',
#  '왜',
#  '부르',
#  '추',
#  '몰리',
#  '제대로',
#  '찍',
#  '안',
#  '믿기',
#  '빛나',
#  '함께',
#  '보이',
#  '모두',
#  '크',
# ...

# %%
# !pip install corpora

# %%
# !pip install konlpy

# %%
import pandas as pd
import re
from gensim import corpora, models
from gensim.models import LdaModel
import pprint

# %%
documents = [total_title]  # Wrap title_keyword inside another list
dictionary = corpora.Dictionary(documents)
corpus = [dictionary.doc2bow(document) for document in documents]

#모델 정의
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=10)

# %%
#7개의 토픽을 뽑은 것!!!
topics = lda_model.print_topics(num_words=7)
for topic in topics:
    print(topic)
# Out:
# (0, '0.035*"함께" + 0.029*"안" + 0.029*"찾" + 0.023*"나오" + 0.023*"타" + 0.023*"만드" + 0.018*"달구"')
# (1, '0.010*"안" + 0.010*"함께" + 0.010*"찾" + 0.010*"보이" + 0.010*"나오" + 0.010*"잘" + 0.010*"만드"')
# (2, '0.010*"찾" + 0.010*"함께" + 0.010*"만드" + 0.010*"타" + 0.010*"달구" + 0.010*"나오" + 0.010*"안"')
# (3, '0.010*"찾" + 0.010*"안" + 0.010*"함께" + 0.010*"만드" + 0.010*"타" + 0.010*"나오" + 0.010*"향하"')
# (4, '0.010*"함께" + 0.010*"찾" + 0.010*"안" + 0.010*"만드" + 0.010*"타" + 0.010*"있" + 0.010*"향하"')

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.035*"함께" + 0.029*"안" + 0.029*"찾" + 0.023*"나오" + 0.023*"타" + 0.023*"만드" + '
#   '0.018*"달구" + 0.018*"있" + 0.018*"예쁘" + 0.018*"보이"'),
#  (1,
#   '0.010*"안" + 0.010*"함께" + 0.010*"찾" + 0.010*"보이" + 0.010*"나오" + 0.010*"잘" + '
#   '0.010*"만드" + 0.010*"예쁘" + 0.010*"있" + 0.010*"향하"'),
#  (2,
#   '0.010*"찾" + 0.010*"함께" + 0.010*"만드" + 0.010*"타" + 0.010*"달구" + 0.010*"나오" + '
#   '0.010*"안" + 0.010*"보이" + 0.010*"향하" + 0.010*"가"'),
#  (3,
#   '0.010*"찾" + 0.010*"안" + 0.010*"함께" + 0.010*"만드" + 0.010*"타" + 0.010*"나오" + '
#   '0.010*"향하" + 0.010*"보이" + 0.010*"예쁘" + 0.010*"달구"'),
#  (4,
#   '0.010*"함께" + 0.010*"찾" + 0.010*"안" + 0.010*"만드" + 0.010*"타" + 0.010*"있" + '
#   '0.010*"향하" + 0.010*"보이" + 0.010*"예쁘" + 0.010*"왜"')]

# %% [markdown]
# ### NNG, VA (선택)

# %%
total_keyword = []

for idx, text in enumerate(total_text) :   #256 개의 기사 (각 기사:text)
    result = kiwi.tokenize(text,stopwords=stopwords) #한 기사에 대한 분석 결과
    # print(idx,'번째 기사 형태소 개수 :',len(result))
    tmp = [token.form for token in result if token.tag in ['NNG','VA']] #한 기사 형태소 리스트
    for idx, word in enumerate(tmp) :
        total_keyword.append(word) #모든 기사 형태소를 total_keyword에 담음

# %%
total_keyword
# Out:
# ['유전자',
#  '팝',
#  '언어',
#  '장벽',
#  '소통',
#  '매개체',
#  '뉴진스',
#  '피프티피프티',
#  '정산',
#  '주장',
#  '사실',
#  '배은망덕',
#  '낙인',
#  '뉴진스',
#  '비치',
#  '백',
#  '담',
#  '파격',
#  '소장',
#  '욕구',
#  '자극',
#  '현장',
#  '르세라핌뉴진스',
#  '걸그룹',
#  '선발',
#  '법',
#  '다르',
#  '후배',
#  '과정',
#  '공개',
#  '하',
#  '이브',
#  '오디션',
#  '알유넥스트',
#  '종합',
#  '팝',
#  '현장',
#  '뉴진스',
#  '사랑',
#  '시스템',
#  '알유넥스트',
#  '보석',
#  '발굴',
#  '르세라핌뉴진스',
#  '후배',
#  '걸그룹',
#  '어떻',
#  '종합',
#  '르세라핌뉴진스의',
#  '후배',
#  '알유넥스트',
#  '소녀',
#  '여정',
#  '시작',
#  '종합',
#  '르세라핌뉴진스',
#  '알',
#  '기대',
#  '이유',
#  '뉴진스',
#  '다음',
#  '종합',
#  '알유넥스트',
#  '소시카',
#  '응원',
#  '걸그룹',
#  '종합',
#  '유',
#  '걸그룹',
#  '발',
#  '종합',
#  '현장',
#  '르세라핌뉴진스',
#  '다음',
#  '알유넥스트',
#  '서바이벌',
#  '표방',
#  '청춘',
#  '성장',
#  '물',
#  '종합',
#  '옆모습',
#  '예술',
#  '미션',
#  '임파서블',
#  '음악',
#  '감사',
#  '인사',
#  '뉴진스',
#  '발레',
#  '코어',
#  '리본',
#  '메리',
#  '인기',
#  '르세라핌뉴진스',
#  '알유넥스트',
#  '욕심',
#  '열정',
#  '금발',
#  '요정',
#  '뉴진스엔',
#  '믹스',
#  '있',
# ...

# %%
news_title = []

for sentence in train['title']:
    news_title.append(sentence)

# %%
total_title = []

for idx, text in enumerate(news_title) :   #256 개의 기사 (각 기사:text)
    result = kiwi.tokenize(text,stopwords=stopwords) #한 기사에 대한 분석 결과
    # print(idx,'번째 기사 형태소 개수 :',len(result))
    tmp = [token.form for token in result if token.tag in ['NNG','VA']] #한 기사 형태소 리스트
    for idx, word in enumerate(tmp) :
        total_title.append(word) #모든 기사 형태소를 total_keyword에 담음

# %%
total_title
# Out:
# ['유전자',
#  '팝',
#  '언어',
#  '장벽',
#  '소통',
#  '매개체',
#  '뉴진스',
#  '피프티피프티',
#  '정산',
#  '주장',
#  '사실',
#  '배은망덕',
#  '낙인',
#  '뉴진스',
#  '비치',
#  '백',
#  '담',
#  '파격',
#  '소장',
#  '욕구',
#  '자극',
#  '현장',
#  '르세라핌뉴진스',
#  '걸그룹',
#  '선발',
#  '법',
#  '다르',
#  '후배',
#  '과정',
#  '공개',
#  '하',
#  '이브',
#  '오디션',
#  '알유넥스트',
#  '종합',
#  '팝',
#  '현장',
#  '뉴진스',
#  '사랑',
#  '시스템',
#  '알유넥스트',
#  '보석',
#  '발굴',
#  '르세라핌뉴진스',
#  '후배',
#  '걸그룹',
#  '어떻',
#  '종합',
#  '르세라핌뉴진스의',
#  '후배',
#  '알유넥스트',
#  '소녀',
#  '여정',
#  '시작',
#  '종합',
#  '르세라핌뉴진스',
#  '알',
#  '기대',
#  '이유',
#  '뉴진스',
#  '다음',
#  '종합',
#  '알유넥스트',
#  '소시카',
#  '응원',
#  '걸그룹',
#  '종합',
#  '유',
#  '걸그룹',
#  '발',
#  '종합',
#  '현장',
#  '르세라핌뉴진스',
#  '다음',
#  '알유넥스트',
#  '서바이벌',
#  '표방',
#  '청춘',
#  '성장',
#  '물',
#  '종합',
#  '옆모습',
#  '예술',
#  '미션',
#  '임파서블',
#  '음악',
#  '감사',
#  '인사',
#  '뉴진스',
#  '발레',
#  '코어',
#  '리본',
#  '메리',
#  '인기',
#  '르세라핌뉴진스',
#  '알유넥스트',
#  '욕심',
#  '열정',
#  '금발',
#  '요정',
#  '뉴진스엔',
#  '믹스',
#  '있',
# ...

# %% [markdown]
# #### ***total title (제목만)

# %%
documents = [total_title]  # Wrap title_keyword inside another list
dictionary = corpora.Dictionary(documents)
corpus = [dictionary.doc2bow(document) for document in documents]

#모델 정의
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=10)

# %%
#7개의 토픽을 뽑은 것!!!
topics = lda_model.print_topics(num_words=10)
topic_list = []

for topic in topics:
    print(topic)
    topic_list.append(topic)
# Out:
# (0, '0.002*"뉴진스" + 0.002*"포토" + 0.002*"종합" + 0.002*"팝" + 0.002*"브랜드" + 0.002*"걸그룹" + 0.002*"표지" + 0.002*"장식" + 0.002*"상반기" + 0.002*"공개"')
# (1, '0.003*"뉴진스" + 0.002*"포토" + 0.002*"팝" + 0.002*"걸그룹" + 0.002*"종합" + 0.002*"공개" + 0.002*"평판" + 0.002*"브랜드" + 0.002*"현장" + 0.002*"표지"')
# (2, '0.003*"뉴진스" + 0.002*"포토" + 0.002*"종합" + 0.002*"팝" + 0.002*"걸그룹" + 0.002*"공개" + 0.002*"평판" + 0.002*"브랜드" + 0.002*"장식" + 0.002*"표지"')
# (3, '0.003*"뉴진스" + 0.002*"걸그룹" + 0.002*"포토" + 0.002*"팝" + 0.002*"종합" + 0.002*"공개" + 0.002*"최초" + 0.002*"브랜드" + 0.002*"상반기" + 0.002*"평판"')
# (4, '0.057*"뉴진스" + 0.017*"팝" + 0.017*"포토" + 0.016*"걸그룹" + 0.013*"종합" + 0.011*"공개" + 0.010*"브랜드" + 0.009*"평판" + 0.009*"표지" + 0.009*"상반기"')

# %%
for topic in topic_list:
    i, scores = topic
    print(scores)
# Out:
# 0.002*"뉴진스" + 0.002*"포토" + 0.002*"종합" + 0.002*"팝" + 0.002*"브랜드" + 0.002*"걸그룹" + 0.002*"표지" + 0.002*"장식" + 0.002*"상반기" + 0.002*"공개"
# 0.003*"뉴진스" + 0.002*"포토" + 0.002*"팝" + 0.002*"걸그룹" + 0.002*"종합" + 0.002*"공개" + 0.002*"평판" + 0.002*"브랜드" + 0.002*"현장" + 0.002*"표지"
# 0.003*"뉴진스" + 0.002*"포토" + 0.002*"종합" + 0.002*"팝" + 0.002*"걸그룹" + 0.002*"공개" + 0.002*"평판" + 0.002*"브랜드" + 0.002*"장식" + 0.002*"표지"
# 0.003*"뉴진스" + 0.002*"걸그룹" + 0.002*"포토" + 0.002*"팝" + 0.002*"종합" + 0.002*"공개" + 0.002*"최초" + 0.002*"브랜드" + 0.002*"상반기" + 0.002*"평판"
# 0.057*"뉴진스" + 0.017*"팝" + 0.017*"포토" + 0.016*"걸그룹" + 0.013*"종합" + 0.011*"공개" + 0.010*"브랜드" + 0.009*"평판" + 0.009*"표지" + 0.009*"상반기"

# %%
# import pandas as pd

# # lda_model.print_topics() 메서드의 출력 결과로부터 키워드와 점수를 추출하는 함수 정의
# def extract_keywords_and_scores(topic):
#     # topic은 튜플 형태로 (토픽 번호, "키워드와 점수들") 형태입니다.
#     topic_num, keyword_string = topic
#     # "키워드와 점수들"에서 키워드와 점수를 추출하여 리스트로 변환합니다.
#     keywords_with_scores = keyword_string.split("+")
#     keywords = [keyword.split("*")[1].strip().strip('"') for keyword in keywords_with_scores]
#     scores = [float(keyword.split("*")[0]) for keyword in keywords_with_scores]
#     return {"topic_num": topic_num, "keywords": keywords, "scores": scores}

# # lda_model.print_topics(num_words=100)의 결과를 topics 변수에 저장했다고 가정합니다.
# # topics = [(1, '0.036*"apple" + 0.031*"fruit" + 0.025*"taste" + ... '), (2, '0.042*"car" + 0.035*"engine" + 0.031*"speed" + ... '), ... ]

# # 토픽별 키워드와 점수를 담을 리스트 생성
# topic_data = []

# # 각 토픽별로 키워드와 점수를 추출하여 topic_data 리스트에 추가
# for topic in topics:
#     topic_data.append(extract_keywords_and_scores(topics))

# # topic_data 리스트를 데이터프레임으로 변환
# df = pd.DataFrame(topic_data)

# # 데이터프레임 출력 (옵션)
# print(df)

# %%
pprint.pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.002*"뉴진스" + 0.002*"포토" + 0.002*"종합" + 0.002*"팝" + 0.002*"브랜드" + '
#   '0.002*"걸그룹" + 0.002*"표지" + 0.002*"장식" + 0.002*"상반기" + 0.002*"공개"'),
#  (1,
#   '0.003*"뉴진스" + 0.002*"포토" + 0.002*"팝" + 0.002*"걸그룹" + 0.002*"종합" + '
#   '0.002*"공개" + 0.002*"평판" + 0.002*"브랜드" + 0.002*"현장" + 0.002*"표지"'),
#  (2,
#   '0.003*"뉴진스" + 0.002*"포토" + 0.002*"종합" + 0.002*"팝" + 0.002*"걸그룹" + '
#   '0.002*"공개" + 0.002*"평판" + 0.002*"브랜드" + 0.002*"장식" + 0.002*"표지"'),
#  (3,
#   '0.003*"뉴진스" + 0.002*"걸그룹" + 0.002*"포토" + 0.002*"팝" + 0.002*"종합" + '
#   '0.002*"공개" + 0.002*"최초" + 0.002*"브랜드" + 0.002*"상반기" + 0.002*"평판"'),
#  (4,
#   '0.057*"뉴진스" + 0.017*"팝" + 0.017*"포토" + 0.016*"걸그룹" + 0.013*"종합" + '
#   '0.011*"공개" + 0.010*"브랜드" + 0.009*"평판" + 0.009*"표지" + 0.009*"상반기"')]

# %%
# keywords_per_topic = [[word for word, prob in lda_model.show_topic(topic_num, topn=10)] for topic_num in range(num_words)]
# keywords_per_topic

# %%
from gensim import models

# Bag-of-words 코퍼스와 사전을 사용하여 5개의 토픽을 가진 LDA 모델 생성
lda_model = models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=5, random_state=100)

# 토픽과 해당 토픽의 상위 10개 키워드를 출력
for idx, topic in lda_model.print_topics(-1, num_words=100):
    print("토픽: {} \n키워드: {}".format(idx, topic))
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 토픽: 0
# ...

# %%
topics = lda_model.show_topics(num_topics=-1, num_words=200, formatted=False)

tmp = []

for topic_id, topic in topics:
    print(f"토픽 {topic_id}:")
    for word, weight in topic:
        print(f"{word}: {weight}")
        tmp.append(word)
    print()
# Out:
# 토픽 0:
# 뉴진스: 0.045066725462675095
# 포토: 0.012323249131441116
# 팝: 0.011963448487222195
# 걸그룹: 0.01126838382333517
# 종합: 0.009601132944226265
# 공개: 0.008749906904995441
# 브랜드: 0.007728181313723326
# 평판: 0.00745671009644866
# 아티스트: 0.007081412244588137
# 표지: 0.007067536003887653
# 르세라핌뉴진스: 0.006968770641833544
# 현장: 0.0067597669549286366
# 알유넥스트: 0.005998038221150637
# 매거진: 0.0058792224153876305
# 최초: 0.005747141316533089
# 장식: 0.005724783521145582
# 세대: 0.005652118939906359
# 상반기: 0.005110723432153463
# 베스트: 0.004895915277302265
# 패션: 0.004530389793217182
# 다음: 0.004523825831711292
# 스톤: 0.004360915627330542
# 송: 0.004267006181180477
# 화보: 0.004156938288360834
# 사랑: 0.0041194180957973
# 블랙: 0.004058193881064653
# 댄스: 0.004053598269820213
# 최고: 0.003993378486484289
# 출시: 0.003988928161561489
# 유명: 0.003950891084969044
# 가수: 0.003863686928525567
# 업: 0.0038449950516223907
# 패키지: 0.003791391383856535
# 차트: 0.003773693460971117
# 글로벌: 0.003753661410883069
# 핑크: 0.003693426726385951
# ...

# %%
len(tmp)
# Out:
# 1000

# %%
set(tmp)

#여기에서 -> 유의미 / 무의미를 우리가 라벨로 구분 (광고 이미지에 영향을 주는지 여부) ->
# Out:
# {'가능',
#  '가수',
#  '가요',
#  '개인',
#  '걸그룹',
#  '겟',
#  '곳',
#  '공개',
#  '공식',
#  '공연',
#  '관왕',
#  '관전',
#  '광고',
#  '그룹',
#  '글로벌',
#  '금',
#  '금발',
#  '꾸밈없',
#  '나이',
#  '논란',
#  '눈부시',
#  '뉴스',
#  '뉴진스',
#  '뉴진스르세라핌',
#  '뉴진스를',
#  '뉴진스블랙핑크아이브',
#  '뉴진스아',
#  '뉴진스엔',
#  '느낌',
#  '다음',
#  '다큐',
#  '단',
#  '단독',
#  '달',
#  '당황',
#  '대가',
#  '대전',
#  '대표',
#  '댄스',
#  '데뷔',
#  '도전',
#  '독보',
#  '뒤태',
#  '디토',
#  '떼창',
#  '레코드',
#  '롱',
#  '룩',
#  '르세라핌뉴진스',
#  '매거진',
#  '매력',
#  '매출',
#  '메뉴',
#  '멤버',
#  '명품',
#  '모두',
#  '무대',
#  '무도',
#  '무한',
#  '문화',
#  '물',
#  '뮤비',
#  '미니',
#  '미모',
#  '미소',
#  '믹스',
#  '반하',
#  '발매',
#  '발표',
#  '방',
#  '방송',
#  '버스',
#  '베스트',
#  '변신',
#  '분석',
#  '브랜드',
#  '블랙',
#  '비주얼',
#  '사',
#  '사랑',
#  '산업',
#  '삶',
#  '상반기',
#  '서',
#  '서머',
#  '서바이벌',
#  '선',
#  '선물',
#  '선정',
#  '선택',
#  '성료',
#  '성수기',
#  '성장',
#  '세대',
#  '센스',
#  '소장',
#  '송',
#  '수업',
#  '순위',
#  '스톤',
#  '스튜디오',
#  '시대',
#  '시선',
#  '시작',
#  '시장',
#  '신곡',
#  '신랑',
#  '신비',
# ...

# %%
len(set(tmp))
# Out:
# 215

# %%
lda_list = list(set(tmp))

# %% [markdown]
# ##### LDA 키워드의 관련도 확인

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 40.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.7 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import pandas as pd

# %%
# 관련도 모델 불러오기
tokenizer = AutoTokenizer.from_pretrained("amberoad/bert-multilingual-passage-reranking-msmarco")
model = AutoModelForSequenceClassification.from_pretrained("amberoad/bert-multilingual-passage-reranking-msmarco")

# %%
# 결과 저장할 리스트 초기화
scores = []

# 모델에 각 기사 제목에 대한 관련도를 계산하여 scores에 저장
for title in lda_list:
    # 쿼리와 문단 생성 (이 모델은 passage reranking을 위한 모델이므로 쿼리는 고정값으로 사용)
    query = "광고 모델"
    passage = title
    inputs = tokenizer.encode_plus(query, passage, return_tensors="pt", padding=True, truncation=True)

    # 모델 추론
    outputs = model(**inputs)
    score = outputs.logits[0][0].item()
    scores.append(score)

# 결과 출력
for i, title in enumerate(lda_list):
    print(f"기사 제목: {title}, 관련도 점수: {scores[i]}")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 기사 제목: 가요, 관련도 점수: 4.018924713134766
# 기사 제목: 신랑, 관련도 점수: 3.063168525695801
# 기사 제목: 성장, 관련도 점수: 2.961066246032715
# 기사 제목: 대가, 관련도 점수: 3.1594884395599365
# 기사 제목: 패션, 관련도 점수: 3.2689623832702637
# 기사 제목: 매력, 관련도 점수: 3.2617554664611816
# 기사 제목: 왕좌, 관련도 점수: 3.4814810752868652
# 기사 제목: 광고, 관련도 점수: 1.167281985282898
# 기사 제목: 분석, 관련도 점수: 2.982929229736328
# 기사 제목: 방, 관련도 점수: 2.7167751789093018
# 기사 제목: 프로듀서, 관련도 점수: 2.892585277557373
# 기사 제목: 뉴진스블랙핑크아이브, 관련도 점수: 3.177031993865967
# 기사 제목: 뉴진스를, 관련도 점수: 3.1707558631896973
# 기사 제목: 시작, 관련도 점수: 3.0070152282714844
# 기사 제목: 스톤, 관련도 점수: 3.1404528617858887
# 기사 제목: 신비, 관련도 점수: 2.9229915142059326
# 기사 제목: 뉴진스, 관련도 점수: 3.309089422225952
# 기사 제목: 인기, 관련도 점수: 1.997469186782837
# 기사 제목: 꾸밈없, 관련도 점수: 2.9235012531280518
# 기사 제목: 시선, 관련도 점수: 3.3059544563293457
# 기사 제목: 입고, 관련도 점수: 2.8906822204589844
# ...

# %%
def get_dataframe(keyword_list, scores):
    data = []
    for i, key in enumerate(keyword_list):
        item = {}
        item["brand"] = key
        item["score"] = scores[i]
        data.append(item)

    df = pd.DataFrame(data)
    return df

# %%
# for i, title in enumerate(lda_list):
#     df = pd.DataFrame({'번호':i, '키워드':title,'점수':score[i] })

df_1 = get_dataframe(lda_list, scores)

# %%
df_1 = df_1.sort_values(by='score', ascending=False)

# %%
# 결과 저장할 리스트 초기화
scores = []

# 모델에 각 기사 제목에 대한 관련도를 계산하여 scores에 저장
for title in lda_list:
    # 쿼리와 문단 생성 (이 모델은 passage reranking을 위한 모델이므로 쿼리는 고정값으로 사용)
    query = "뉴진스"
    passage = title
    inputs = tokenizer.encode_plus(query, passage, return_tensors="pt", padding=True, truncation=True)

    # 모델 추론
    outputs = model(**inputs)
    score = outputs.logits[0][0].item()
    scores.append(score)

# 결과 출력
for i, title in enumerate(lda_list):
    print(f"기사 제목: {title}, 관련도 점수: {scores[i]}")
# Out:
# 기사 제목: 가요, 관련도 점수: 4.4527587890625
# 기사 제목: 신랑, 관련도 점수: 3.8972363471984863
# 기사 제목: 성장, 관련도 점수: 3.2702600955963135
# 기사 제목: 대가, 관련도 점수: 3.7228763103485107
# 기사 제목: 패션, 관련도 점수: 3.6993377208709717
# 기사 제목: 매력, 관련도 점수: 3.7269091606140137
# 기사 제목: 왕좌, 관련도 점수: 4.007382869720459
# 기사 제목: 광고, 관련도 점수: 3.3347039222717285
# 기사 제목: 분석, 관련도 점수: 3.2588844299316406
# 기사 제목: 방, 관련도 점수: 2.899679660797119
# 기사 제목: 프로듀서, 관련도 점수: 3.174114227294922
# 기사 제목: 뉴진스블랙핑크아이브, 관련도 점수: -2.0969226360321045
# 기사 제목: 뉴진스를, 관련도 점수: 1.8435592651367188
# 기사 제목: 시작, 관련도 점수: 3.5052225589752197
# 기사 제목: 스톤, 관련도 점수: 3.18404221534729
# 기사 제목: 신비, 관련도 점수: 3.310607433319092
# 기사 제목: 뉴진스, 관련도 점수: 0.5893621444702148
# 기사 제목: 인기, 관련도 점수: 2.5213735103607178
# 기사 제목: 꾸밈없, 관련도 점수: 3.219413995742798
# 기사 제목: 시선, 관련도 점수: 3.478123188018799
# 기사 제목: 입고, 관련도 점수: 3.262935161590576
# 기사 제목: 청춘, 관련도 점수: 3.706275463104248
# 기사 제목: 아티스트, 관련도 점수: 3.2724173069000244
# 기사 제목: 퀸, 관련도 점수: 2.7713325023651123
# ...

# %%
# for i, title in enumerate(lda_list):
#     df = pd.DataFrame({'번호':i, '키워드':title,'점수':score[i] })

df_2 = get_dataframe(lda_list, scores)

# %%
df2 = df_2.sort_values(by='score', ascending=False)

# %%
df_1
# Out:
#     brand     score
# 0      가요  4.018925
# 67    휴양지  3.833927
# 113    나이  3.824677
# 81     파격  3.738646
# 117    여름  3.718595
# ..    ...       ...
# 17     인기  1.997469
# 188    출시  1.981468
# 116    공식  1.666932
# 7      광고  1.167282
# 51     데뷔  0.891540
#
# [215 rows x 2 columns]

# %%
df_2
# Out:
#     brand     score
# 0      가요  4.452759
# 1      신랑  3.897236
# 2      성장  3.270260
# 3      대가  3.722876
# 4      패션  3.699338
# ..    ...       ...
# 210   에이셉  3.322075
# 211    이유  2.884403
# 212    조명  3.016461
# 213  스튜디오  3.315937
# 214    순위  3.899607
#
# [215 rows x 2 columns]

# %%
df_1 = df_1.rename(columns={0: 'brand', 1: '광고모델 관련도'})
df_2 = df_2.rename(columns={0: 'brand', 1: '뉴진스 관련도'})

df = df_1["brand"]

df = pd.merge(df,df_1,on="brand",how="left")
df = pd.merge(df,df_2,on="brand",how="left")

df
# Out:
#     brand   score_x   score_y
# 0      가요  4.018925  4.452759
# 1     휴양지  3.833927  3.602024
# 2      나이  3.824677  3.818501
# 3      파격  3.738646  3.841964
# 4      여름  3.718595  3.694630
# ..    ...       ...       ...
# 210    인기  1.997469  2.521374
# 211    출시  1.981468  2.843809
# 212    공식  1.666932  2.703334
# 213    광고  1.167282  3.334704
# 214    데뷔  0.891540  2.811884
#
# [215 rows x 3 columns]

# %% [markdown]
# #### total keyword (본문 전체)

# %%
documents = [total_keyword]  # Wrap title_keyword inside another list
dictionary = corpora.Dictionary(documents)
corpus = [dictionary.doc2bow(document) for document in documents]

# %%
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=10)

# %%
topics = lda_model.print_topics(num_words=7)
for topic in topics:
    print(topic)
# Out:
# (0, '0.002*"뉴진스" + 0.002*"포토" + 0.002*"팝" + 0.002*"걸그룹" + 0.002*"종합" + 0.002*"공개" + 0.002*"브랜드"')
# (1, '0.002*"뉴진스" + 0.002*"팝" + 0.002*"포토" + 0.002*"걸그룹" + 0.002*"브랜드" + 0.002*"공개" + 0.002*"알유넥스트"')
# (2, '0.058*"뉴진스" + 0.017*"포토" + 0.017*"팝" + 0.016*"걸그룹" + 0.013*"종합" + 0.011*"공개" + 0.010*"브랜드"')
# (3, '0.002*"뉴진스" + 0.002*"포토" + 0.002*"팝" + 0.002*"걸그룹" + 0.002*"브랜드" + 0.002*"종합" + 0.002*"평판"')
# (4, '0.004*"뉴진스" + 0.002*"팝" + 0.002*"걸그룹" + 0.002*"포토" + 0.002*"종합" + 0.002*"브랜드" + 0.002*"평판"')

# %%
from gensim import models

# Bag-of-words 코퍼스와 사전을 사용하여 5개의 토픽을 가진 LDA 모델 생성
lda_model = models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=5, random_state=100)

# 토픽과 해당 토픽의 상위 10개 키워드를 출력
for idx, topic in lda_model.print_topics(-1, num_words=100):
    print("토픽: {} \n키워드: {}".format(idx, topic))
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 토픽: 0
# ...

# %%
topics = lda_model.show_topics(num_topics=-1, num_words=100, formatted=False)


for topic_id, topic in topics:
    print(f"토픽 {topic_id}:")
    for word, weight in topic:
        print(f"{word}: {weight}")
    print()
# Out:
# 토픽 0:
# 뉴진스: 0.045066725462675095
# 포토: 0.012323249131441116
# 팝: 0.011963448487222195
# 걸그룹: 0.01126838382333517
# 종합: 0.009601132944226265
# 공개: 0.008749906904995441
# 브랜드: 0.007728181313723326
# 평판: 0.00745671009644866
# 아티스트: 0.007081412244588137
# 표지: 0.007067536003887653
# 르세라핌뉴진스: 0.006968770641833544
# 현장: 0.0067597669549286366
# 알유넥스트: 0.005998038221150637
# 매거진: 0.0058792224153876305
# 최초: 0.005747141316533089
# 장식: 0.005724783521145582
# 세대: 0.005652118939906359
# 상반기: 0.005110723432153463
# 베스트: 0.004895915277302265
# 패션: 0.004530389793217182
# 다음: 0.004523825831711292
# 스톤: 0.004360915627330542
# 송: 0.004267006181180477
# 화보: 0.004156938288360834
# 사랑: 0.0041194180957973
# 블랙: 0.004058193881064653
# 댄스: 0.004053598269820213
# 최고: 0.003993378486484289
# 출시: 0.003988928161561489
# 유명: 0.003950891084969044
# 가수: 0.003863686928525567
# 업: 0.0038449950516223907
# 패키지: 0.003791391383856535
# 차트: 0.003773693460971117
# 글로벌: 0.003753661410883069
# 핑크: 0.003693426726385951
# ...

# %% [markdown]
# #### total_keyword_list (keyword.txt)

# %%
total_keyword_list
# Out:
# ['꾸밈없 즐기 뽐내 소개 가사 돋보이 그러 제공 대신 채우 신시사이저 등장 내비치 이하 키우 장난 일으키 부연 비유 노래 신드롬 탈피 진정 패션 현지 잡지 매거진 가깝 이중 뉴진스는 강조 걸그룹 서로 매개체 코러스 미학 언어 음악 향상 매력 표현 홈페이지 게재 선사 단체 하나 공개 표지 공감 만큼 기여 기자 적합 이재훈 의미 장식 데뷔 금지',
# %%
total_word_list = []

for i in range(len(total_keyword_list)):
    total_keyword_list[i] = total_keyword_list[i].replace(' ',',')

# %%
total_keyword_list
# Out:
# ['꾸밈없,즐기,뽐내,소개,가사,돋보이,그러,제공,대신,채우,신시사이저,등장,내비치,이하,키우,장난,일으키,부연,비유,노래,신드롬,탈피,진정,패션,현지,잡지,매거진,가깝,이중,뉴진스는,강조,걸그룹,서로,매개체,코러스,미학,언어,음악,향상,매력,표현,홈페이지,게재,선사,단체,하나,공개,표지,공감,만큼,기여,기자,적합,이재훈,의미,장식,데뷔,금지',
#  '진단,의사,증상,대응,것이다피프티피프티가,상태,찍히,보내,싸늘하,밟히,워너,하다피프티피프티,수술,코리아,공식,맞대응,전면,제공,해지,사실,불러오,전속,일시,전하,들어주,의학,드문,데뷔,위반,상황,정지,난타전,이러하,제기,나타나,개입,낙인,외주,심문,중대,공전,파괴,잠정,어트랙트와,서울중앙지법,조치,중단,행보,스케줄,용역,연예,강조,휴식기,아이브,수식어,작용,업체,최근',
#  '출시,하니,소개,앞서,비치,샤이,엽서,꾸미,선보이,사지,뉴진스를,뉴진스서울뉴스,앨범,소장,스티커,가지,사각,데뷔,황미,모습,다니,미니,파격,가볍,뉴진스민지,담기,화이트,가방,어깨,공개,눈길,키링,버니,포토북,핑크,혜인,다이어리,폭발,취향,소재,뉴진스,소속사,지나,활용,해린,다음,실제,반응,카드,마크,다니엘,포토,자극,슈퍼,기자,버전,멤버,블루',
#  '참가,참석,세계,만들,화제,글로벌,현장,스튜디오잼머쉬룸컴퍼니의,자리매김,소개,참여,생각,알유,대중,참고,발표회,인원,오늘,소수,생활,이현,기존,진행,영재,단독,전문,이야기,차세대,대상,국내,주도,제공,데뷔조,년대,프로젝트,커리큘럼,의도,과시,방식,여기,연출자,지금,야생마,자라,밝히,출연,중복,본인,임하,자신,기획,고유,그렇,관리,생기,엔터테인먼트,이렇,회상',
# ...

# %%
total_join_list = ','.join(total_keyword_list)

# %%
documents = [total_keyword_list]  # Wrap title_keyword inside another list
dictionary = corpora.Dictionary(documents)
corpus = [dictionary.doc2bow(document) for document in documents]

# %%
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=10)

# %%
topics = lda_model.print_topics(num_words=1)
for topic in topics:
    print(topic)
# Out:
# (0, '0.004*"기자,사진빌리프랩,제작사,이끌,뉴스,프로필,방송,멤버,사진,제공,목소리,등장,전하,당부,비롯하,걸그룹,보내,스튜디오잼머쉬룸컴퍼니,영상,머쉬룸,각오,공개,방시혁,공동,자신,기대,컴퍼니,내달리,알유넥스트의,유튜브,빌리프랩,갖추,스튜디오,박수,모이,끌어올리,하이브,향하,처음,스토리,드리,알유넥스트,응원,당차,총출동,엔하이픈,글로벌,이상,경연,데뷔,가운데,개인,모습,아이돌,일부,아티스트,국내,최선"')
# (1, '0.004*"타이틀곡,크레이지,롤링,연예,이후,노래,음반,발표,느끼,머물,음악,큐피드,뉴진스,메인,베스트,걸그룹,방탄소년단,상반기,연상,지수,라이크,지민,핑크,잡지,오르,년대,평가,발매,뉴스,싱글,피프티,정점,이름,빌보드,스톤,올리,올해,기자,최고,세기,매력,차트,블랙,기록,순위,선정,미국,목록,지혜"')
# 뉴스,기자,사진빌리프랩하이브,걸그룹,글로벌,방송,최근,단체,화제,국내,세계,사진빌리프랩,공개,컴퍼니,공동,멤버,방시혁,머쉬룸,빌리프랩의,빌리프랩,혜원,필두,후우나,모아,사진,알유넥스트,아이리스이로하,제작사,전하,서연,히메나,지현,각자,차세대,통일,업로드,비주얼,영상,에나,새롭,뉴진스를,이사,윤아,하이브,지우,미소,모카,원흐,모으,정은,환하,향하,연습실,레이블즈,샤넬,여정,기대,이미지: 0.00392061797901988
#
# 토픽 4:
# ...

# %% [markdown]
# - 토픽간에 겹치는 단어가 너무 많아서, 유사도 덜 높은 것들을 추출
# -  혹은 불용어 사전

# %%
# from gensim.models import LdaModel
# from gensim.matutils import hellinger

# # LDA 모델 생성
# lda_model = LdaModel(corpus=corpus, id2word=id2word, num_topics=5)

# # 토픽 간의 유사도 계산
# def compute_topic_similarity(lda_model):
#     num_topics = lda_model.num_topics
#     topic_similarity = []

#     for i in range(num_topics):
#         for j in range(i + 1, num_topics):
#             topic1 = lda_model.show_topic(i)
#             topic2 = lda_model.show_topic(j)
#             similarity = hellinger(topic1, topic2)
#             topic_similarity.append((i, j, similarity))

#     return topic_similarity

# topic_similarity = compute_topic_similarity(lda_model)

# # 유사도가 낮은 순서대로 정렬
# topic_similarity.sort(key=lambda x: x[2])

# # 유사도가 낮은 토픽끼리 출력
# for i, j, similarity in topic_similarity:
#     if similarity < 0.3:  # 임의로 유사도의 임계값을 설정하여 출력
#         print(f"토픽 {i}: {lda_model.show_topic(i)}")
#         print(f"토픽 {j}: {lda_model.show_topic(j)}")

# %%
#LDA로 차원 축소하기
# from sklearn.decomposition import LatentDirichletAllocation
# import joblib
# lda_model = joblib.load(f"{DATA_PATH}lda_model_200.pkl")

# %% [markdown]
# ## B. LDA 통일데이터 작업 (txt)

# %%
with open(f"{DATA_PATH}sample.txt") as f:
    text = f.read()

text = [text]

# %% [markdown]
# ### 키위 + LDA

# %%
# !pip install kiwipiepy

# %%
from kiwipiepy import Kiwi
kiwi = Kiwi()

# %%
from kiwipiepy.utils import Stopwords
stopwords =  Stopwords()
# stopwords.stopwords # 불용어 리스트

# %%
result = kiwi.tokenize(text)
result

# %%
kiwi_total_keyword = []

for idx, text in enumerate(total_text) :   #256 개의 기사 (각 기사:text)
    result = kiwi.tokenize(text,stopwords=stopwords) #한 기사에 대한 분석 결과
    # print(idx,'번째 기사 형태소 개수 :',len(result))
    tmp = [token.form for token in result if token.tag in ['VV','VA','NNG','MAG']] #한 기사 형태소 리스트
    for idx, word in enumerate(tmp) :
        kiwi_total_keyword.append(word) #모든 기사 형태소를 total_keyword에 담음


#형태소 : len(token.form) != 1 and token.tag[0] in "NV" or token.tag[0].startswith('SL')

# %%
kiwi_total_keyword
# Out:
# ['유전자',
#  '팝',
#  '언어',
#  '장벽',
#  '넘',
#  '소통',
#  '매개체',
#  '뉴진스',
#  '피프티피프티',
#  '정산',
#  '주장',
#  '사실',
#  '배은망덕',
#  '낙인',
#  '뉴진스',
#  '비치',
#  '백',
#  '담',
#  '파격',
#  '소장',
#  '욕구',
#  '자극',
#  '현장',
#  '르세라핌뉴진스',
#  '만드',
#  '걸그룹',
#  '선발',
#  '법',
#  '다르',
#  '후배',
#  '과정',
#  '공개',
#  '하',
#  '이브',
#  '오디션',
#  '알유넥스트',
#  '종합',
#  '팝',
#  '현장',
#  '뉴진스',
#  '사랑',
#  '시스템',
#  '알유넥스트',
#  '보석',
#  '발굴',
#  '찾',
#  '르세라핌뉴진스',
#  '후배',
#  '걸그룹',
#  '어떻',
#  '종합',
#  '르세라핌뉴진스의',
#  '후배',
#  '알유넥스트',
#  '소녀',
#  '여정',
#  '시작',
#  '종합',
#  '르세라핌뉴진스',
#  '알',
#  '기대',
#  '이유',
#  '뉴진스',
#  '다음',
#  '종합',
#  '알유넥스트',
#  '소시카',
#  '응원',
#  '걸그룹',
#  '종합',
#  '알',
#  '유',
#  '걸그룹',
#  '발',
#  '종합',
#  '현장',
#  '르세라핌뉴진스',
#  '다음',
#  '알유넥스트',
#  '서바이벌',
#  '표방',
#  '청춘',
#  '성장',
#  '물',
#  '종합',
#  '옆모습',
#  '예술',
#  '미션',
#  '임파서블',
#  '음악',
#  '감사',
#  '인사',
#  '뉴진스',
#  '빠지',
#  '발레',
#  '코어',
#  '리본',
#  '메리',
#  '인기',
#  '르세라핌뉴진스',
#  '알유넥스트',
#  '욕심',
#  '열정',
#  '보이',
# ...

# %%
documents = [kiwi_total_keyword]  # Wrap title_keyword inside another list
dictionary = corpora.Dictionary(documents)
corpus = [dictionary.doc2bow(document) for document in documents]

#모델 정의
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=10)

# %%
#7개의 토픽을 뽑은 것!!!
topics = lda_model.print_topics(num_words=10)
topic_list = []

for topic in topics:
    print(topic)
    topic_list.append(topic)
# Out:
# (0, '0.002*"뉴진스" + 0.002*"포토" + 0.002*"걸그룹" + 0.002*"팝" + 0.002*"종합" + 0.002*"브랜드" + 0.002*"평판" + 0.002*"표지" + 0.002*"상반기" + 0.002*"공개"')
# (1, '0.052*"뉴진스" + 0.015*"포토" + 0.015*"팝" + 0.015*"걸그룹" + 0.012*"종합" + 0.010*"공개" + 0.009*"브랜드" + 0.008*"평판" + 0.008*"장식" + 0.008*"상반기"')
# (2, '0.002*"뉴진스" + 0.002*"팝" + 0.002*"걸그룹" + 0.002*"종합" + 0.002*"포토" + 0.002*"공개" + 0.002*"매거진" + 0.002*"표지" + 0.002*"상반기" + 0.002*"브랜드"')
# (3, '0.002*"뉴진스" + 0.002*"포토" + 0.002*"걸그룹" + 0.002*"팝" + 0.002*"종합" + 0.002*"브랜드" + 0.002*"공개" + 0.002*"평판" + 0.002*"르세라핌뉴진스" + 0.002*"장식"')
# (4, '0.003*"뉴진스" + 0.002*"팝" + 0.002*"걸그룹" + 0.002*"포토" + 0.002*"브랜드" + 0.002*"종합" + 0.002*"현장" + 0.002*"장식" + 0.002*"알유넥스트" + 0.002*"표지"')

# %%
for topic in topic_list:
    i, scores = topic
    print(scores)
# Out:
# 0.002*"뉴진스" + 0.002*"포토" + 0.002*"걸그룹" + 0.002*"팝" + 0.002*"종합" + 0.002*"브랜드" + 0.002*"평판" + 0.002*"표지" + 0.002*"상반기" + 0.002*"공개"
# 0.052*"뉴진스" + 0.015*"포토" + 0.015*"팝" + 0.015*"걸그룹" + 0.012*"종합" + 0.010*"공개" + 0.009*"브랜드" + 0.008*"평판" + 0.008*"장식" + 0.008*"상반기"
# 0.002*"뉴진스" + 0.002*"팝" + 0.002*"걸그룹" + 0.002*"종합" + 0.002*"포토" + 0.002*"공개" + 0.002*"매거진" + 0.002*"표지" + 0.002*"상반기" + 0.002*"브랜드"
# 0.002*"뉴진스" + 0.002*"포토" + 0.002*"걸그룹" + 0.002*"팝" + 0.002*"종합" + 0.002*"브랜드" + 0.002*"공개" + 0.002*"평판" + 0.002*"르세라핌뉴진스" + 0.002*"장식"
# 0.003*"뉴진스" + 0.002*"팝" + 0.002*"걸그룹" + 0.002*"포토" + 0.002*"브랜드" + 0.002*"종합" + 0.002*"현장" + 0.002*"장식" + 0.002*"알유넥스트" + 0.002*"표지"

# %%
from gensim import models

# Bag-of-words 코퍼스와 사전을 사용하여 5개의 토픽을 가진 LDA 모델 생성
kiwi_lda_model = models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=5, random_state=100)

# 토픽과 해당 토픽의 상위 10개 키워드를 출력
for idx, topic in kiwi_lda_model.print_topics(-1, num_words=100):
    print("토픽: {} \n키워드: {}".format(idx, topic))
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 토픽: 0
# ...

# %%
# remove_word_list = ['있','함께','선보이','보이','많','가장','특히','밝히','전하','또한','지금','가지']
# #불용어 리스트 작업 필요

# %%
topics = kiwi_lda_model.show_topics(num_topics=-1, num_words=200, formatted=False)

kiwi_tmp = []

for topic_id, topic in topics:
    print(f"토픽 {topic_id}:")
    for word, weight in topic:
        print(f"{word}: {weight}")
        kiwi_tmp.append(word)
    print()
# Out:
# 토픽 0:
# 뉴진스: 0.042351946234703064
# 팝: 0.014319448731839657
# 걸그룹: 0.013348373584449291
# 포토: 0.011717176996171474
# 종합: 0.009628277271986008
# 공개: 0.00824238732457161
# 평판: 0.008032409474253654
# 브랜드: 0.007141736801713705
# 표지: 0.00631650909781456
# 매거진: 0.006227829959243536
# 현장: 0.0059885429218411446
# 상반기: 0.005953792482614517
# 알유넥스트: 0.005810147617012262
# 최초: 0.005304229445755482
# 장식: 0.005294495727866888
# 다음: 0.004406337160617113
# 아티스트: 0.00435046199709177
# 르세라핌뉴진스: 0.0043386295437812805
# 세대: 0.004227453377097845
# 송: 0.004175906535238028
# 차트: 0.003998082131147385
# 화보: 0.0037643888499587774
# 함께: 0.0037292311899363995
# 겟: 0.0037198930513113737
# 패션: 0.003646698547527194
# 출시: 0.0035907793790102005
# 댄스: 0.0035869949497282505
# 유명: 0.003542077261954546
# 핑크: 0.00340612162835896
# 시작: 0.00330541655421257
# 위버스콘: 0.003281824756413698
# 무대: 0.0032785004004836082
# 사랑: 0.003227590350434184
# 스톤: 0.0031732413917779922
# 안: 0.0031708371825516224
# 컴백: 0.003144080052152276
# ...

# %%
len(kiwi_tmp)
# Out:
# 1000

# %%
set(kiwi_tmp)
# Out:
# {'가',
#  '가능',
#  '가수',
#  '가요',
#  '개인',
#  '걸그룹',
#  '겟',
#  '곳',
#  '공개',
#  '공식',
#  '공연',
#  '관왕',
#  '관전',
#  '광고',
#  '그룹',
#  '글로벌',
#  '금',
#  '금발',
#  '깜짝',
#  '꾸밈없',
#  '나',
#  '나오',
#  '나이',
#  '넘기',
#  '논란',
#  '뉴스',
#  '뉴진스',
#  '뉴진스르세라핌',
#  '뉴진스를',
#  '뉴진스블랙핑크아이브',
#  '뉴진스아',
#  '뉴진스엔',
#  '느낌',
#  '다음',
#  '다큐',
#  '단',
#  '단독',
#  '달',
#  '달구',
#  '당황',
#  '대전',
#  '대표',
#  '댄스',
#  '데뷔',
#  '도전',
#  '독보',
#  '뒤태',
#  '디토',
#  '떼창',
#  '또',
#  '레코드',
#  '룩',
#  '르세라핌뉴진스',
#  '만드',
#  '말',
#  '매거진',
#  '매력',
#  '매출',
#  '메뉴',
#  '멤버',
#  '명품',
#  '모두',
#  '모르',
#  '몰리',
#  '무대',
#  '무도',
#  '문화',
#  '물',
#  '뮤비',
#  '미니',
#  '미모',
#  '미소',
#  '믹스',
#  '반하',
#  '발매',
#  '발표',
#  '방',
#  '방송',
#  '버스',
#  '베스트',
#  '변신',
#  '보이',
#  '분석',
#  '브랜드',
#  '블랙',
#  '비주얼',
#  '빛나',
#  '빠지',
#  '사',
#  '사랑',
#  '산업',
#  '삶',
#  '상반기',
#  '서머',
#  '서바이벌',
#  '선',
#  '선물',
#  '선정',
#  '선택',
#  '성료',
#  '성장',
#  '세대',
#  '소장',
#  '송',
#  '수업',
#  '순위',
#  '스톤',
#  '스튜디오',
# ...

# %%
len(set(kiwi_tmp))
# Out:
# 223

# %%
kiwi_lda_list = list(set(kiwi_tmp))

# %% [markdown]
# #### 관련도 분석
# - 관련도 분석으로 넘어가면 급격히 추상화 되는 느낌임
# - LDA까지 하고 수동으로 발라내는 것도?

# %%
# 결과 저장할 리스트 초기화
scores = []

# 모델에 각 기사 제목에 대한 관련도를 계산하여 scores에 저장
for title in kiwi_lda_list:
    # 쿼리와 문단 생성 (이 모델은 passage reranking을 위한 모델이므로 쿼리는 고정값으로 사용)
    query = "광고 모델"
    passage = title
    inputs = tokenizer.encode_plus(query, passage, return_tensors="pt", padding=True, truncation=True)

    # 모델 추론
    outputs = model(**inputs)
    score = outputs.logits[0][0].item()
    scores.append(score)

# 결과 출력
for i, title in enumerate(kiwi_lda_list):
    print(f"기사 제목: {title}, 관련도 점수: {scores[i]}")
# Out:
# 기사 제목: 가요, 관련도 점수: 4.018924713134766
# 기사 제목: 신랑, 관련도 점수: 3.063168525695801
# 기사 제목: 성장, 관련도 점수: 2.961066246032715
# 기사 제목: 패션, 관련도 점수: 3.2689623832702637
# 기사 제목: 매력, 관련도 점수: 3.2617554664611816
# 기사 제목: 광고, 관련도 점수: 1.167281985282898
# 기사 제목: 분석, 관련도 점수: 2.982929229736328
# 기사 제목: 방, 관련도 점수: 2.7167751789093018
# 기사 제목: 프로듀서, 관련도 점수: 2.892585277557373
# 기사 제목: 뉴진스블랙핑크아이브, 관련도 점수: 3.177031993865967
# 기사 제목: 뉴진스를, 관련도 점수: 3.1707558631896973
# 기사 제목: 시작, 관련도 점수: 3.0070152282714844
# 기사 제목: 스톤, 관련도 점수: 3.1404528617858887
# 기사 제목: 신비, 관련도 점수: 2.9229915142059326
# 기사 제목: 뉴진스, 관련도 점수: 3.309089422225952
# 기사 제목: 인기, 관련도 점수: 1.997469186782837
# 기사 제목: 꾸밈없, 관련도 점수: 2.9235012531280518
# 기사 제목: 시선, 관련도 점수: 3.3059544563293457
# 기사 제목: 입고, 관련도 점수: 2.8906822204589844
# 기사 제목: 청춘, 관련도 점수: 3.2542777061462402
# 기사 제목: 아티스트, 관련도 점수: 2.898303747177124
# 기사 제목: 퀸, 관련도 점수: 2.74342679977417
# 기사 제목: 베스트, 관련도 점수: 2.993180274963379
# 기사 제목: 선, 관련도 점수: 2.9615697860717773
# 기사 제목: 음원, 관련도 점수: 3.382185935974121
# ...

# %%
def get_dataframe(keyword_list, scores):
    data = []
    for i, key in enumerate(keyword_list):
        item = {}
        item["brand"] = key
        item["score"] = scores[i]
        data.append(item)

    df = pd.DataFrame(data)
    return df

# %%
# for i, title in enumerate(lda_list):
#     df = pd.DataFrame({'번호':i, '키워드':title,'점수':score[i] })

df = get_dataframe(kiwi_lda_list, scores)
df = df.sort_values(by='score', ascending=False)

df
# Out:
#     brand     score
# 0      가요  4.018925
# 69    휴양지  3.833927
# 116    나이  3.824677
# 83     파격  3.738646
# 120    여름  3.718595
# ..    ...       ...
# 15     인기  1.997469
# 194    출시  1.981468
# 121    공식  1.666932
# 5      광고  1.167282
# 52     데뷔  0.891540
#
# [223 rows x 2 columns]

# %% [markdown]
# ### Spacy + LDA

# %%
# !python -m spacy download ko_core_news_sm
# Out:
# 2023-07-28 04:39:04.442338: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 35.5 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('ko_core_news_sm')

# %%
import spacy
nlp = spacy.load('ko_core_news_sm')

# %%
with open(f"{DATA_PATH}sample.txt") as f:
    text = f.read()

text = text

# %%
doc = nlp(text)
doc
# Out:
# 새로운 유전자 뉴진스 K팝 언어장벽 넘어 소통하는 매개체 패션잡지 V 매거진 78월호 표지 장식인터뷰 서울뉴시스 뉴진스 미국 패션 잡지 V매거진 표지 20230630 사진   V MAGAZINE 제공 photonewsiscom 재판매 및 DB 금지서울뉴시스이재훈 기자  K팝은 언어 장벽을 넘어 사람들이 함께 즐기고 소통할 수 있는 하나의 매개체 역할을 한다신드롬 걸그룹 뉴진스NewJeans 미국 패션 잡지 V 매거진V MAGAZINE 78월호 표지를 장식했다 뉴진스는 지난 26일이하 현지시간부터 29일까지 V 매거진 홈페이지에 게재된 인터뷰에서 음악에 대한 열정을 내비쳤다 이들은 트레이닝 시간이 매우 특별했다며 춤과 노래를 향상시킬 수 있는 기회였고 음악에 대한 열정이 깊어지는 시간이었다고 말했다 그러면서 우리는 그 과정을 통해 서로에게 더 가까워졌고 음악에 대한 열정도 함께 키울 수 있었다고 덧붙였다V 매거진은 뉴진스의 단체 및 개인 이미지를 차례로 공개했다 뉴진스는 표지에서 당당하고 도도한 매력을 뽐냈다 V 매거진은 뉴진스에 대해 새로운 유전자라는 이름의 이중적인 의미에 적합하게 글로벌 음악 신scene에서 K팝이 더 돋보일 수 있도록 기여했다고 소개했다 또한 데뷔와 함께 돌풍을 일으킨 뉴진스의 등장에 대해 빅뱅에 비유할 만큼 폭발적이라고 표현했다  또 V 매거진은 뉴진스의 진정성을 강조하며 이들은 10대들이 공감할 수 있는 장난기 많고 꾸밈없는 미학을 선사한다고 봤다 이어 뉴진스의 음악 또한 이러한 진정성이 돋보인다 코러스 대신 신시사이저를 채우는 흐름을 탈피하고 멤버들이 직접 작사에 참여한 코러스 가사들로 노래를 채운다고 부연했다 뉴진스도 아니고 피프티피프티 정산주장 사실상 배은망덕 낙인 그룹 피프티피프티 소속사 제공빌보드를 수놓은 괴물 신인 피프티피프티의 행보가 남다르다 히트곡 1곡 데뷔 7개월 만에 정산 미비 등을 이유로 소속사와 계약 해지를 요구하고 있다 연예계에서도 드문 파격 행보이기도 하다피프티피프티 소속사 어트랙트와 용역 외주 업체 더기버
# ...

# %%
spacy_total_keyword = []
for article in tqdm(doc):
    doc = nlp(article)
    tokens = [token.text for token in doc]
    t = " ".join(set(tokens))
    spacy_total_keyword.append(t)

spacy_total_keyword
# Out:
#   0%|          | 0/73572 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-c5e60ef099b0> in <cell line: 2>()
#       1 spacy_total_keyword = []
#       2 for article in tqdm(doc):
# ----> 3     doc = nlp(article)
#       4     tokens = [token.text for token in doc]
#       5     t = " ".join(set(tokens))
#
# /usr/local/lib/python3.10/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1005         DOCS: https://spacy.io/api/language#call
#    1006         """
# -> 1007         doc = self._ensure_doc(text)
#    1008         if component_cfg is None:
#    1009             component_cfg = {}
#
# /usr/local/lib/python3.10/dist-packages/spacy/language.py in _ensure_doc(self, doc_like)
#    1099         if isinstance(doc_like, bytes):
#    1100             return Doc(self.vocab).from_bytes(doc_like)
# ...

# %%
spacy_total_keyword = extractions_spacy
spacy_total_keyword

len(spacy_total_keyword), len(kiwi_total_keyword) #kiwi나 spacy나 동일 텍스트 토큰화 했을때 토큰 개수가 동일했음

# %%
documents = [spacy_total_keyword]  # Wrap title_keyword inside another list
dictionary = corpora.Dictionary(documents)
corpus = [dictionary.doc2bow(document) for document in documents]

#모델 정의
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=10)

# %%
#7개의 토픽을 뽑은 것!!!
topics = lda_model.print_topics(num_words=10)
topic_list = []

for topic in topics:
    print(topic)
    topic_list.append(topic)

# %%
for topic in topic_list:
    i, scores = topic
    print(scores)

# %%
from gensim import models

# Bag-of-words 코퍼스와 사전을 사용하여 5개의 토픽을 가진 LDA 모델 생성
lda_model = models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=5, random_state=100)

# 토픽과 해당 토픽의 상위 10개 키워드를 출력
for idx, topic in lda_model.print_topics(-1, num_words=100):
    print("토픽: {} \n키워드: {}".format(idx, topic))

# %%
# remove_word_list = ['있','함께','선보이','보이','많','가장','특히','밝히','전하','또한','지금','가지']
#불용어 리스트 작업 필요

# %%
topics = lda_model.show_topics(num_topics=-1, num_words=200, formatted=False)

spacy_tmp = []

for topic_id, topic in topics:
    print(f"토픽 {topic_id}:")
    for word, weight in topic:
        print(f"{word}: {weight}")
        spacy_tmp.append(word)
    print()

# %%
len(tmp)

# %%
set(tmp)

# %%
len(set(tmp))

# %%
spacy_lda_list = list(set(tmp))

# %% [markdown]
# #### 관련도 분석
# - 관련도 분석으로 넘어가면 급격히 추상화 되는 느낌임
# - LDA까지 하고 수동으로 발라내는 것도?

# %%
# 결과 저장할 리스트 초기화
scores = []

# 모델에 각 기사 제목에 대한 관련도를 계산하여 scores에 저장
for title in kiwi_lda_list:
    # 쿼리와 문단 생성 (이 모델은 passage reranking을 위한 모델이므로 쿼리는 고정값으로 사용)
    query = "광고 모델"
    passage = title
    inputs = tokenizer.encode_plus(query, passage, return_tensors="pt", padding=True, truncation=True)

    # 모델 추론
    outputs = model(**inputs)
    score = outputs.logits[0][0].item()
    scores.append(score)

# 결과 출력
for i, title in enumerate(lda_list):
    print(f"기사 제목: {title}, 관련도 점수: {scores[i]}")

# %%
def get_dataframe(keyword_list, scores):
    data = []
    for i, key in enumerate(keyword_list):
        item = {}
        item["brand"] = key
        item["score"] = scores[i]
        data.append(item)

    df = pd.DataFrame(data)
    return df

# %%
# for i, title in enumerate(lda_list):
#     df = pd.DataFrame({'번호':i, '키워드':title,'점수':score[i] })

df = get_dataframe(kiwi_lda_list, scores)
df = df.sort_values(by='score', ascending=False)

df

# %%
# !pip install keybert

# %%
import keybert
from keybert import KeyBERT

# %%
keybert_model = KeyBERT()

# %%
test = keybert_model.extract_keywords(extractions_spacy, keyphrase_ngram_range=(1, 1), stop_words=None)
# df_spacy = pd.DataFrame(test)
# # df_spacy.columns = ['spacy_keyword', 'spacy_score']
# df_spacy

test

# %% [markdown]
# # 참고

# %% [markdown]
# ## 2_TF_IDF

# %%
news_title

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

text = news_title

tfidf_vectorizer = TfidfVectorizer()

tfidf_matrix = tfidf_vectorizer.fit_transform(text)

# Get the feature names (words)
feature_names = tfidf_vectorizer.get_feature_names_out()

tfidf_scores = tfidf_matrix.toarray()[0]

# # Sort the words based on their TF-IDF scores
# sorted_keywords = [word for _, word in sorted(zip(tfidf_scores, feature_names), reverse=True)]

# print(sorted_keywords[:5])  # Print the top 5 keywords

zip(tfidf_scores, feature_names)

for i in zip(tfidf_scores, feature_names):
    print(i)

# %% [markdown]
# ## 3_Word Rank / Text Rank / Summa

# %%
pip install summa

# %%
from summa import keywords

text_list = news_title

# Convert each sentence to Unicode format and get keywords using TextRank
text_keywords_list = [keywords.keywords(sentence, words=5) for sentence in text_list]

print(text_keywords_list)  # Print the keywords for each sentence

# %% [markdown]
# ## 4_Rake

# %%
# !pip install nltk

# %%
from rake_nltk import Rake

# Sample text data
text = text

# Create the Rake object
r = Rake()

# Extract keywords
r.extract_keywords_from_text(text)

# Get the top keywords
keywords = r.get_ranked_phrases_with_scores()

print(keywords[:5])  # Print the top 5 keywords with scores

# %% [markdown]
# ## 5_YAKE

# %%
# !pip install yake

# %%
import yake

text = text

# Create the YAKE extractor
extractor = yake.KeywordExtractor()

# Extract keywords
keywords = extractor.extract_keywords(text)

print(keywords[:5])  # Print the top 5 keywords

# %%
# !pip install krwordrank

# %%
import krwordrank
import yake
from summa import keywords as textrank_keywords
import pandas as pd

text_list = news_title
news_title

# %%
krwordrank.

# %%
#  RAKE
def extract_rake_keywords(sentences_list):
    rake = krwordrank.extractor.RakeExtractor()
    keywords_list = [rake.extract_keywords(sentence, min_num_of_words=1, max_num_of_words=1) for sentence in sentences_list]
    return keywords_list

extract_rake_keywords(news_title)
